# %% [markdown]
# # Web Scraping

# %%
#Creamos un dataframe vacío con las columnas donde guardaremos todos los datos para la base de datos sacados mediante web scraping
import pandas as pd
df = pd.DataFrame(columns=["Nombre de la receta", "Link de la receta", "Tiempo de preparación", "Dificultad", "Coste por persona", "Ingredientes", "Link de la imagen"])
df.head()
# Out:
# Empty DataFrame
# Columns: [Nombre de la receta, Link de la receta, Tiempo de preparación, Dificultad, Coste por persona, Ingredientes, Link de la imagen]
# Index: []

# %%
#Empezamos el web scraping
import requests
import regex as re
from bs4 import BeautifulSoup

url ='https://www.recetasderechupete.com/recetas-faciles/'

page = requests.get(url)

soup = BeautifulSoup(page.content,'html.parser')
#Guardamos en una lista todo el código html de todas las recetas buscando el elemento clave <div id='itemreceta ....'>
#Cada elemento de la lista será el código html de una receta.
listarecetas = soup.find_all('div', {'class': re.compile(r'^itemreceta')})
len(listarecetas)
# Out:
# 937

# %%
#Aquí creamos listas para guardar todos los datos para luego llevarlos al dataframe
#Es posible que pudiéramos hacerlo directamente pero de momento lo he hecho así.
nombres = []
links = []
dificultades = [] 
tiempos = []
costes = []
imagenes = []
#Bucle que hace el scraping recogiendo todos los datos de la página principal pero sin los ingredientes.
for receta in listarecetas:
    nombres.append(receta.find_all("h2")[0].getText())
    link = receta.find_all("a", href=True)
    for el in link:
        linkreceta = el['href']
        links.append(linkreceta)
    dificultades.append(receta.find_all("li")[0].getText().split(' · ')[0])
    tiempos.append(receta.find_all("li")[0].getText().split(' · ')[1])
    costes.append(receta.find_all("li")[1].getText())
    for img in receta.find_all("img"):
        imagenes.append(img['src'])

# %%
#Guardamos en el dataframe creado arriba de todo las listas con todos los datos del punto anterior.
df["Nombre de la receta"] = nombres
df["Link de la receta"] = links
df["Dificultad"] = dificultades
df["Tiempo de preparación"] = tiempos
df["Coste por persona"] = costes
df["Link de la imagen"] = imagenes

# %%
df.head(5)
# Out:
#                                  Nombre de la receta  \
# 0             Tarta de queso fácil. Receta sin horno
# 1                    Cómo preparar merengue italiano
# 2                               Frixuelos asturianos
# 3  Tosta de salmón y naranja. Aperitivo fácil y d...
# 4                     Vichyssoise o crema de puerros
#
#                                    Link de la receta Tiempo de preparación  \
# 0  https://www.recetasderechupete.com/receta-faci...                25 min
# 1  https://www.recetasderechupete.com/como-prepar...                15 min
# 2  https://www.recetasderechupete.com/frixuelos-a...                40 min
# 3  https://www.recetasderechupete.com/receta-de-t...                10 min
# 4  https://www.recetasderechupete.com/vichyssoise...                35 min
#
#   Dificultad  Coste por persona Ingredientes  \
# 0      Fácil   0.5€ por persona          NaN
# 1      Fácil   0.4€ por persona          NaN
# 2      Fácil   0.3€ por persona          NaN
# 3      Fácil  0.35€ por persona          NaN
# 4      Fácil   0.8€ por persona          NaN
#
#                                    Link de la imagen
# 0  https://www.recetasderechupete.com/wp-content/...
# 1  https://www.recetasderechupete.com/wp-content/...
# 2  https://www.recetasderechupete.com/wp-content/...
# 3  https://www.recetasderechupete.com/wp-content/...
# 4  https://www.recetasderechupete.com/wp-content/...

# %%
#Creamos la lista que guardará todos los ingredientes y luego la pasaremos al dataframe.
ingredientes = []
#Bucle que hace el scraping cogiendo los links de cada receta del dataframe y busca y guarda los ingredientes en una lista.
for url_receta in df['Link de la receta']:
    page = requests.get(url_receta)
    soup = BeautifulSoup(page.content,'html.parser')
    divingredientes = soup.find_all('div', {'id': 'ingredients'})
    ingredientes_de_la_receta = []
    for ingrediente in divingredientes:
        for li in ingrediente.findAll('li'):
            ingredientes_de_la_receta.append(li.getText())
    ingredientes.append(ingredientes_de_la_receta)

# %%
#Pasamos la lista de ingredientes al dataframe
df['Ingredientes'] = ingredientes

# %%
df.tail()
# Out:
#                                    Nombre de la receta  \
# 932            Galaktoboureko o pastel de leche griego
# 933  Fideos japoneses (Udon Noodle) con pollo al curry
# 934                    Bizcocho de cerezas de Vilariño
# 935                 Espaguetis con pollo y champiñones
# 936                  Ensalada Gigli con atún y anchoas
#
#                                      Link de la receta Tiempo de preparación  \
# 932  https://www.recetasderechupete.com/receta-de-g...                50 min
# 933  https://www.recetasderechupete.com/receta-de-f...                25 min
# 934  https://www.recetasderechupete.com/receta-de-b...                40 min
# 935  https://www.recetasderechupete.com/receta-de-e...                45 min
# 936  https://www.recetasderechupete.com/receta-de-e...                25 min
#
#     Dificultad  Coste por persona  \
# 932      Fácil  0.35€ por persona
# 933      Fácil   1.2€ por persona
# 934      Fácil  0.75€ por persona
# 935      Fácil   0.9€ por persona
# 936      Fácil     1€ por persona
#
#                                           Ingredientes  \
# 932  [6 huevos, 300 g de azúcar, 150 g de sémola fi...
# 933  [2 cebollas, 1/2 pimiento morrón, 100 g de bro...
# 934  [300 g de harina de trigo., 200 g de azúcar bl...
# 935  [2 cebollas, 2 zanahorias, Sal y pimienta reci...
# 936  [1 bolsa de pasta Capricci o similar, 2 latas ...
#
#                                      Link de la imagen
# 932  https://www.recetasderechupete.com/wp-content/...
# 933  https://www.recetasderechupete.com/wp-content/...
# 934  https://www.recetasderechupete.com/wp-content/...
# 935  https://www.recetasderechupete.com/wp-content/...
# 936  https://www.recetasderechupete.com/wp-content/...

# %%
#Guardamos el dataframe con ingredientes en un archivo .csv
df.to_csv('data/recetasfaciles.csv', encoding ='utf-8-sig')

# %% [markdown]
# # Cleaning the ingredients

# %%
#No es para el código final pero es para nosotros, bucle para contar el número de ingredientes totales que hay, incluye repetidos.
listaingredientes = list(df[df['Ingredientes'].notna()].Ingredientes)
sumaingredientes = 0
for receta in listaingredientes:
    for ingrediente in receta:
        sumaingredientes += 1
sumaingredientes# Web Scraping for ingredients
# Out:
# 8103

# %%
#Limpieza de los ingredientes
lista_limpia = md.limpieza(listaingredientes)        
len(set(lista_limpia))
# Out:
# 2470

# %%
# guardamos los ingredientes en un dataframe.
dfingredientes = pd.DataFrame(data = set(lista_limpia), columns = ['Ingredientes'])
dfingredientes.to_csv('data/Ingredientes.csv', encoding ='utf-8-sig')

# %%
misingredientes = ['salmón', 'aguacate', 'sal']
recetas = []
for i in range(len(df)):
    cuenta = 0
    for miingrediente in misingredientes:
        for ingrediente in df.loc[i, 'Ingredientes']:
            if miingrediente in ingrediente:
                cuenta +=1 
    if cuenta == len(misingredientes):
        recetas.append(df.loc[i, ['Nombre de la receta', 'Ingredientes']])

dfencontradas = pd.DataFrame(data=recetas, columns=['Nombre de la receta', 'Ingredientes'])
dfencontradas.head()
dfencontradas.to_csv('data/encontradas.csv', encoding ='utf-8-sig')

# %%
dfencontradas
# Out:
#                                    Nombre de la receta  \
# 27   Ensalada de pasta con salmón y aguacate. La co...
# 96                Ensalada de arroz, aguacate y salmón
# 99   Cómo hacer quesadillas de pollo y queso. 2 rec...
# 116  Ensalada Waldorf con pollo. Receta fácil y del...
# 121  Cómo hacer huevos rancheros. Receta de un desa...
# 230                           Tostas de salmón ahumado
# 274  Dorada a la sal. Receta fácil para un pescado ...
# 289  Cómo hacer 5 canapés navideños fáciles y sabro...
# 302      Arepas rellenas de aguacate, pollo y mayonesa
# 313  Albóndigas de salmón y langostinos. Receta con...
# 387  Fusilli alla norma. Receta siciliana de pasta ...
# 411                        Tacos veganos en 15 minutos
# 434                           Alitas de pollo al horno
# 445                        Timbal de verduras con pavo
# 485                         Lubina a la sal y al horno
# 626        Alitas de pollo al horno con salsa barbacoa
# 701  Pollo al limón con arroz blanco. Receta china ...
# 753                          Salsa rosa casera y fácil
# 788         Pavo relleno de Navidad al cava y cítricos
# 886  Ensalada templada al wok con queso azul Fourme...
# 904  Ensalada de marisco con brotes de lechuga, tom...
# 920               Ensalada marinera o Salade Marinière
#
#                                           Ingredientes
# 27   [300 g. pasta Elicoidali de Garofalo, 200 g. d...
# 96   [4 vasitos arroz basmati Brillante, 200 g. sal...
# 99   [Ingredientes para las quesadillas de pollo y ...
# 116  [Para la salsa Waldorf: 250 g. de mayonesa, El...
# 121  [4 tomates pera maduros, 2 chiles serranos, ½ ...
# 230  [100 g. de salmón ahumado, 4 rebanadas de pan ...
# 274  [2 doradas de ración (600-700 gramos cada una)...
# 289  [Para las cestitas de aguacate y mango: 1 agua...
# 302  [Para las arepas: 300 g. de agua, 200 g. de ha...
# 313  [4 rodajas de salmón (200 g. cada una), 300 g....
# 387  [400 g. fusilli de Garofalo, 2 berenjenas, 400...
# 411  [8 tortillas para tacos, 400 g. de frijoles, 2...
# 434  [1 kg. de alitas de pollo, Para el adobo inici...
# 445  [1 berenjena, 1 calabacín grande, 2 tomates, 2...
# 485  [2 lubinas de ración (600 gramos cada una). , ...
# 626  [1,5 kg. de alitas de pollo, 1 cebolla y 2 die...
# 701  [500 g de contramuslo de pollo deshuesado (o p...
# 753  [Para hacer la mayonesa: 200 ml. aceite de oli...
# 788  [1 pavo relleno de Navidad con nueces, ciruela...
# 886  [2 bolsas de tu ensalada mezclum preferida, 2 ...
# 904  [1 bolsa de 400 g de ensalada variada (brotes ...
# 920  [1 bolsa de 175 g. de ensalada variada (brotes...
