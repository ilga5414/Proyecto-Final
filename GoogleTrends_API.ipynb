# %% [markdown]
# # Collecting the Google Trends API

# %%
# %%capture
# !pip install pytrends
#!pip install python-dotenv

# %% [markdown]
# ## Connecting to Google

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %% [markdown]
# ## Interest By Region

# %%
pytrend.build_payload(kw_list=['Taylor Swift'])
# Interest by Region
df = pytrend.interest_by_region()
df.head(10)
# Out:
#                    Taylor Swift
# geoName
# Afghanistan                   0
# Albania                       0
# Algeria                      13
# American Samoa                0
# Andorra                       0
# Angola                        0
# Anguilla                      0
# Antarctica                    0
# Antigua & Barbuda             0
# Argentina                    19

# %%
df.reset_index().plot(x='geoName', y='Taylor Swift', figsize=(120, 10), kind ='bar')
# Out:
# <AxesSubplot:xlabel='geoName'>

# %% [markdown]
# ## Daily Search Trends

# %%
# Get Google Hot Trends data
df = pytrend.trending_searches(pn='united_states')
df.head()
# Out:
#                     0
# 0      Loki episode 4
# 1  Zion National Park
# 2              Ohtani
# 3         Raj Kaushal
# 4         Myocarditis

# %%
df = pytrend.today_searches(pn='US')

# %% [markdown]
# ## Top Charts
# Let was see what was trending in 2019. With the help of top_charts method we can get the top trending searches yearly.

# %%
# Get Google Top Charts
df = pytrend.top_charts(2019, hl='en-US', tz=300, geo='GLOBAL')
df.head()
# Out:
#                    title exploreQuery
# 0  India vs South Africa
# 1          Cameron Boyce
# 2           Copa America
# 3    Bangladesh vs India
# 4              iPhone 11

# %% [markdown]
# ## Google Keyword Suggestions

# %%
# Get Google Keyword Suggestions
keywords = pytrend.suggestions(keyword='Mercedes Benz')
df = pd.DataFrame(keywords)
df.drop(columns= 'mid')   # This column makes no sense
# Out:
#                      title                     type
# 0            Mercedes-Benz  Luxury vehicles company
# 1            Mercedes-Benz          Automobile make
# 2    Mercedes-Benz C-Class               Luxury car
# 3    Mercedes-Benz E-Class               Luxury car
# 4  Mercedes-Benz GLC-Class             Compact suvs

# %% [markdown]
# ## Related Queries

# %%
pytrend.build_payload(kw_list=['Coronavirus'])

# %%
# Related Queries, returns a dictionary of dataframes
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/miniconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/miniconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/miniconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~/miniconda3/lib/python3.9/http/client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~/miniconda3/lib/python3.9/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~/miniconda3/lib/python3.9/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~/miniconda3/lib/python3.9/socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# ~/miniconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~/miniconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/miniconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/miniconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/miniconda3/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# ~/miniconda3/lib/python3.9/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     734                 raise value.with_traceback(tb)
# --> 735             raise value
#     736         finally:
#
# ~/miniconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/miniconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     429             raise
#
# ~/miniconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     334         if isinstance(err, SocketTimeout):
# --> 335             raise ReadTimeoutError(
#     336                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#
# ReadTimeoutError: HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-20-76ab316e7bdf> in <module>
#       1 # Related Queries, returns a dictionary of dataframes
# ----> 2 related_queries = pytrend.related_queries()
#       3 related_queries.values()
#
# ~/miniconda3/lib/python3.9/site-packages/pytrends/request.py in related_queries(self)
#     367
#     368             # parse the returned json
# --> 369             req_json = self._get_data(
#     370                 url=TrendReq.RELATED_QUERIES_URL,
#     371                 method=TrendReq.GET_METHOD,
#
# ~/miniconda3/lib/python3.9/site-packages/pytrends/request.py in _get_data(self, url, method, trim_chars, **kwargs)
#     124                               cookies=self.cookies, **kwargs, **self.requests_args)  # DO NOT USE retries or backoff_factor here
#     125         else:
# --> 126             response = s.get(url, timeout=self.timeout, cookies=self.cookies,
#     127                              **kwargs, **self.requests_args)   # DO NOT USE retries or backoff_factor here
#     128         # check if the response contains json and throw an exception otherwise
#
# ~/miniconda3/lib/python3.9/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# ~/miniconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/miniconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)

# %%
# Related Topics, returns a dictionary of dataframes
related_topic = pytrend.related_topics()
related_topic.values()
# Out:
# dict_values([{'rising':      value formattedValue                                            link  \
# 0   188750       Breakout  /trends/explore?q=/g/11ckxx4f1g&date=today+5-y
# 1    40400       Breakout      /trends/explore?q=/m/07l88z&date=today+5-y
# 2    36750       Breakout       /trends/explore?q=/m/09kvv&date=today+5-y
# 3    33250       Breakout  /trends/explore?q=/g/11j8qdq0kc&date=today+5-y
# 4    28500       Breakout       /trends/explore?q=/m/069q9&date=today+5-y
# 5    24900       Breakout      /trends/explore?q=/m/0chgr2&date=today+5-y
# 6    24200       Breakout       /trends/explore?q=/m/0bzty&date=today+5-y
# 7     2800        +2,800%       /trends/explore?q=/m/03rjj&date=today+5-y
# 8     2600        +2,600%       /trends/explore?q=/m/09nm_&date=today+5-y
# 9     2150        +2,150%       /trends/explore?q=/m/06mnr&date=today+5-y
# 10    1250        +1,250%       /trends/explore?q=/m/06mkj&date=today+5-y
# 11     600          +600%       /trends/explore?q=/m/0294j&date=today+5-y
# 12     550          +550%  /trends/explore?q=/g/11fsrytkzq&date=today+5-y
#
#         topic_mid                          topic_title  \
# 0   /g/11ckxx4f1g                         Worldometers
# 1       /m/07l88z                             Lockdown
# 2        /m/09kvv             Johns Hopkins University
# 3   /g/11j8qdq0kc                     COVID-19 testing
# 4        /m/069q9                           Quarantine
# 5       /m/0chgr2                             Victoria
# 6        /m/0bzty                             Lombardy
# 7        /m/03rjj                                Italy
# 8        /m/09nm_                                World
# 9        /m/06mnr                           Statistics
# 10       /m/06mkj                                Spain
# 11       /m/0294j                                Death
# 12  /g/11fsrytkzq  2020 coronavirus pandemic in France
#
#                                    topic_type
# 0                                     Website
# 1                                       Topic
# 2   Private university in Baltimore, Maryland
# 3                                       Topic
# 4                                       Topic
# 5                                   Australia
# 6                              Italian region
# 7                           Country in Europe
# 8                                       Topic
# 9                                  Discipline
# 10                                    Country
# 11                                      Topic
# 12                                      Event  , 'top':     value formattedValue  hasData  \
# 0     100            100     True
# 1       4              4     True
# 2       4              4     True
# 3       3              3     True
# 4       2              2     True
# 5       2              2     True
# 6       2              2     True
# 7       2              2     True
# 8       2              2     True
# 9       1              1     True
# 10      1              1     True
# 11      1              1     True
# 12      0             <1     True
# 13      0             <1     True
# 14      0             <1     True
# 15      0             <1     True
# 16      0             <1     True
# 17      0             <1     True
#
#                                               link      topic_mid  \
# 0       /trends/explore?q=/m/01cpyy&date=today+5-y      /m/01cpyy
# 1        /trends/explore?q=/m/0294j&date=today+5-y       /m/0294j
# 2       /trends/explore?q=/m/01b_06&date=today+5-y      /m/01b_06
# 3        /trends/explore?q=/m/03rjj&date=today+5-y       /m/03rjj
# 4        /trends/explore?q=/m/09nm_&date=today+5-y       /m/09nm_
# 5        /trends/explore?q=/m/0g9pc&date=today+5-y       /m/0g9pc
# 6   /trends/explore?q=/g/11ckxx4f1g&date=today+5-y  /g/11ckxx4f1g
# 7        /trends/explore?q=/m/06mkj&date=today+5-y       /m/06mkj
# 8        /trends/explore?q=/m/07__7&date=today+5-y       /m/07__7
# 9        /trends/explore?q=/m/06mnr&date=today+5-y       /m/06mnr
# 10  /trends/explore?q=/g/11j8_9sv06&date=today+5-y  /g/11j8_9sv06
# 11  /trends/explore?q=/g/11fsrytkzq&date=today+5-y  /g/11fsrytkzq
# 12      /trends/explore?q=/m/07l88z&date=today+5-y      /m/07l88z
# 13       /trends/explore?q=/m/09kvv&date=today+5-y       /m/09kvv
# 14  /trends/explore?q=/g/11j8qdq0kc&date=today+5-y  /g/11j8qdq0kc
# 15       /trends/explore?q=/m/069q9&date=today+5-y       /m/069q9
# 16      /trends/explore?q=/m/0chgr2&date=today+5-y      /m/0chgr2
# 17       /trends/explore?q=/m/0bzty&date=today+5-y       /m/0bzty
#
#                             topic_title  \
# 0                           Coronavirus
# 1                                 Death
# 2                               Symptom
# 3                                 Italy
# 4                                 World
# 5                                 Virus
# 6                          Worldometers
# 7                                 Spain
# 8                               Vaccine
# 9                            Statistics
# 10                     COVID-19 vaccine
# 11  2020 coronavirus pandemic in France
# 12                             Lockdown
# 13             Johns Hopkins University
# 14                     COVID-19 testing
# 15                           Quarantine
# 16                             Victoria
# 17                             Lombardy
#
#                                    topic_type
# 0                                       Virus
# 1                                       Topic
# 2                                       Topic
# 3                           Country in Europe
# 4                                       Topic
# 5                            Infectious agent
# 6                                     Website
# 7                                     Country
# 8                                       Topic
# 9                                  Discipline
# 10                             Pharmaceutical
# 11                                      Event
# 12                                      Topic
# 13  Private university in Baltimore, Maryland
# 14                                      Topic
# 15                                      Topic
# 16                                  Australia
# 17                             Italian region  }])
